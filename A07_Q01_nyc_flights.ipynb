# %% [markdown]
# NYCFlights dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'D:\Msc DS\sem-2\PY assigments\A-07\nyc_flights.csv')
df
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336776 entries, 0 to 336775
# Data columns (total 20 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   year            336776 non-null  int64
#  1   month           336776 non-null  int64
#  2   day             336776 non-null  int64
#  3   dep_time        328521 non-null  float64
#  4   sched_dep_time  336776 non-null  int64
#  5   dep_delay       328521 non-null  float64
#  6   arr_time        328063 non-null  float64
#  7   sched_arr_time  336776 non-null  int64
#  8   arr_delay       327346 non-null  float64
#  9   carrier         336776 non-null  object
#  10  flight          336776 non-null  int64
#  11  tailnum         334264 non-null  object
#  12  origin          336776 non-null  object
#  13  dest            336776 non-null  object
#  14  air_time        327346 non-null  float64
#  15  distance        336776 non-null  int64
# ...

# %%
df.shape
# Out:
# (336776, 20)

# %%
df = df.drop(['WeekEnd (Y/N)'], axis = 1)
df
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
df.dropna(inplace = True)
df
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336765  2013      9   30    2240.0            2245       -5.0    2334.0
# 336766  2013      9   30    2240.0            2250      -10.0    2347.0
# 336767  2013      9   30    2241.0            2246       -5.0    2345.0
# 336768  2013      9   30    2307.0            2255       12.0    2359.0
# 336769  2013      9   30    2349.0            2359      -10.0     325.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %% [markdown]
# ### 1. List all flights scheduled for 1 Jan

# %%
jan = df[(df["month"] == 1) & (df["day"] == 1)]
jan
# Out:
#      year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0    2013      1    1     517.0             515        2.0     830.0
# 1    2013      1    1     533.0             529        4.0     850.0
# 2    2013      1    1     542.0             540        2.0     923.0
# 3    2013      1    1     544.0             545       -1.0    1004.0
# 4    2013      1    1     554.0             600       -6.0     812.0
# ..    ...    ...  ...       ...             ...        ...       ...
# 833  2013      1    1    2327.0            2250       37.0      32.0
# 834  2013      1    1    2343.0            1724      379.0     314.0
# 835  2013      1    1    2353.0            2359       -6.0     425.0
# 836  2013      1    1    2353.0            2359       -6.0     418.0
# 837  2013      1    1    2356.0            2359       -3.0     425.0
#
#      sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# ...

# %% [markdown]
# ### 2. Find flights that were not delayed more than 2 hours

# %%
delay = df[df["dep_delay"] <= 120]
delay
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336765  2013      9   30    2240.0            2245       -5.0    2334.0
# 336766  2013      9   30    2240.0            2250      -10.0    2347.0
# 336767  2013      9   30    2241.0            2246       -5.0    2345.0
# 336768  2013      9   30    2307.0            2255       12.0    2359.0
# 336769  2013      9   30    2349.0            2359      -10.0     325.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %% [markdown]
# ### 3. Find all flights

# %% [markdown]
# #### a. Had an delay of 2 or more hours

# %%
a = df[df["dep_delay"] >= 120]
a
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 151     2013      1    1     848.0            1835      853.0    1001.0
# 218     2013      1    1     957.0             733      144.0    1056.0
# 268     2013      1    1    1114.0             900      134.0    1447.0
# 491     2013      1    1    1540.0            1338      122.0    2020.0
# 649     2013      1    1    1815.0            1325      290.0    2120.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336579  2013      9   30    1823.0            1545      158.0    1934.0
# 336668  2013      9   30    1951.0            1649      182.0    2157.0
# 336724  2013      9   30    2053.0            1815      158.0    2310.0
# 336757  2013      9   30    2159.0            1845      194.0    2344.0
# 336763  2013      9   30    2235.0            2001      154.0      59.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %% [markdown]
# #### b. Flew to Houston (IAH or HOU)

# %%
airports = ["IAH", "HOU"]
b = df[df["dest"].isin(airports)]
b
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 32      2013      1    1     623.0             627       -4.0     933.0
# 81      2013      1    1     728.0             732       -4.0    1041.0
# 89      2013      1    1     739.0             739        0.0    1104.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336524  2013      9   30    1729.0            1720        9.0    2001.0
# 336527  2013      9   30    1735.0            1715       20.0    2010.0
# 336618  2013      9   30    1859.0            1859        0.0    2134.0
# 336694  2013      9   30    2015.0            2015        0.0    2244.0
# 336737  2013      9   30    2105.0            2106       -1.0    2329.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %% [markdown]
# #### c. Were operated by Unites, American or Delta

# %%
flights = ["UA", "AA", "DL"]
c = df[df["carrier"].isin(flights)]
c
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# 5       2013      1    1     554.0             558       -4.0     740.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336737  2013      9   30    2105.0            2106       -1.0    2329.0
# 336744  2013      9   30    2121.0            2100       21.0    2349.0
# 336751  2013      9   30    2140.0            2140        0.0      10.0
# 336755  2013      9   30    2149.0            2156       -7.0    2245.0
# 336762  2013      9   30    2233.0            2113       80.0     112.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %% [markdown]
# #### d. Departed in summer(March, April , May)

# %%
d = df[(df["month"] >= 3) & (df["month"] <= 5)]
d
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 136247  2013      3    1       4.0            2159      125.0     318.0
# 136248  2013      3    1      50.0            2358       52.0     526.0
# 136249  2013      3    1     117.0            2245      152.0     223.0
# 136250  2013      3    1     454.0             500       -6.0     633.0
# 136251  2013      3    1     505.0             515      -10.0     746.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 222186  2013      5   31    2307.0            2055      132.0     139.0
# 222187  2013      5   31    2313.0            2245       28.0      19.0
# 222188  2013      5   31    2315.0            2220       55.0     244.0
# 222189  2013      5   31    2355.0            2359       -4.0     338.0
# 222190  2013      5   31    2355.0            2359       -4.0     335.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %% [markdown]
# #### e. Arrived more than 2 hours late but didn’t leave late

# %%
e = df[(df["dep_delay"] <= 0) & (df["arr_delay"] >= 120)]
e
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 22911   2013      1   27    1419.0            1420       -1.0    1754.0
# 33011   2013     10    7    1350.0            1350        0.0    1736.0
# 33019   2013     10    7    1357.0            1359       -2.0    1858.0
# 41075   2013     10   16     657.0             700       -3.0    1258.0
# 55985   2013     11    1     658.0             700       -2.0    1329.0
# 152766  2013      3   18    1844.0            1847       -3.0      39.0
# 180893  2013      4   17    1635.0            1640       -5.0    2049.0
# 181270  2013      4   18     558.0             600       -2.0    1149.0
# 181327  2013      4   18     655.0             700       -5.0    1213.0
# 213693  2013      5   22    1827.0            1830       -3.0    2217.0
# 214512  2013      5   23    1810.0            1810        0.0    2208.0
# 226434  2013      6    5    1604.0            1615      -11.0    2041.0
# ...

# %% [markdown]
# #### f. Departed between midnight and 6.00 am

# %%
df["dep_time"] = pd.to_datetime(df["dep_time"], format = '%H%M', errors = 'coerce')
f = df[(df["dep_time"].dt.hour >= 0) & (df["dep_time"].dt.hour < 6)]
f
# Out:
#         year  month  day            dep_time  sched_dep_time  dep_delay  \
# 0       2013      1    1 1900-01-01 05:17:00             515        2.0
# 1       2013      1    1 1900-01-01 05:33:00             529        4.0
# 2       2013      1    1 1900-01-01 05:42:00             540        2.0
# 3       2013      1    1 1900-01-01 05:44:00             545       -1.0
# 4       2013      1    1 1900-01-01 05:54:00             600       -6.0
# ...      ...    ...  ...                 ...             ...        ...
# 335800  2013      9   30 1900-01-01 05:57:00             600       -3.0
# 335801  2013      9   30 1900-01-01 05:57:00             600       -3.0
# 335802  2013      9   30 1900-01-01 05:57:00             600       -3.0
# 335803  2013      9   30 1900-01-01 05:58:00             600       -2.0
# 335804  2013      9   30 1900-01-01 05:58:00             600       -2.0
#
#         arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin  \
# ...

# %% [markdown]
# ### 4. Sort flights to find most delayed flight

# %%
sorted_flights = df.sort_values("arr_delay", ascending = False)
sorted_flights.iloc[0]
# Out:
# year                              2013
# month                                1
# day                                  9
# dep_time           1900-01-01 06:41:00
# sched_dep_time                     900
# dep_delay                       1301.0
# arr_time                        1242.0
# sched_arr_time                    1530
# arr_delay                       1272.0
# carrier                             HA
# flight                              51
# tailnum                         N384HA
# origin                             JFK
# dest                               HNL
# air_time                         640.0
# distance                          4983
# hour                                 9
# minute                               0
# time_hour         2013-01-09T14:00:00Z
# Name: 7072, dtype: object

# %% [markdown]
# ### 5. Which flights travelled longest?

# %%
df["distance_covered"] = df["distance"] * 1.609344
sorted_flights = df.sort_values("distance_covered", ascending=False)
sorted_flights.iloc[0]
# Out:
# year                                2013
# month                                 11
# day                                    4
# dep_time             1900-01-01 10:02:00
# sched_dep_time                      1000
# dep_delay                            2.0
# arr_time                          1558.0
# sched_arr_time                      1555
# arr_delay                            3.0
# carrier                               HA
# flight                                51
# tailnum                           N393HA
# origin                               JFK
# dest                                 HNL
# air_time                           636.0
# distance                            4983
# hour                                  10
# minute                                 0
# time_hour           2013-11-04T15:00:00Z
# distance_covered             8019.361152
# Name: 58763, dtype: object

# %% [markdown]
# ### 6. What are different ways to select dept_time, dept_delay,arr_time and arr_delay from flights

# %%
# 1. Using the column names:
selected_columns_1 = df[["dep_time", "dep_delay", "arr_time", "arr_delay"]]
selected_columns_1
# Out:
#                   dep_time  dep_delay  arr_time  arr_delay
# 0      1900-01-01 05:17:00        2.0     830.0       11.0
# 1      1900-01-01 05:33:00        4.0     850.0       20.0
# 2      1900-01-01 05:42:00        2.0     923.0       33.0
# 3      1900-01-01 05:44:00       -1.0    1004.0      -18.0
# 4      1900-01-01 05:54:00       -6.0     812.0      -25.0
# ...                    ...        ...       ...        ...
# 336765 1900-01-01 22:40:00       -5.0    2334.0      -17.0
# 336766 1900-01-01 22:40:00      -10.0    2347.0      -20.0
# 336767 1900-01-01 22:41:00       -5.0    2345.0      -16.0
# 336768 1900-01-01 23:07:00       12.0    2359.0        1.0
# 336769 1900-01-01 23:49:00      -10.0     325.0      -25.0
#
# [327346 rows x 4 columns]

# %%
# 2. Using the column indices
selected_columns_2 = df.iloc[:, [4, 6, 7, 8]]
selected_columns_2
# Out:
#         sched_dep_time  arr_time  sched_arr_time  arr_delay
# 0                  515     830.0             819       11.0
# 1                  529     850.0             830       20.0
# 2                  540     923.0             850       33.0
# 3                  545    1004.0            1022      -18.0
# 4                  600     812.0             837      -25.0
# ...                ...       ...             ...        ...
# 336765            2245    2334.0            2351      -17.0
# 336766            2250    2347.0               7      -20.0
# 336767            2246    2345.0               1      -16.0
# 336768            2255    2359.0            2358        1.0
# 336769            2359     325.0             350      -25.0
#
# [327346 rows x 4 columns]

# %%
# 3. Using the `loc[]` method:
selected_columns_3 = df.loc[:, ["dep_time", "dep_delay", "arr_time", "arr_delay"]]
selected_columns_3
# Out:
#                   dep_time  dep_delay  arr_time  arr_delay
# 0      1900-01-01 05:17:00        2.0     830.0       11.0
# 1      1900-01-01 05:33:00        4.0     850.0       20.0
# 2      1900-01-01 05:42:00        2.0     923.0       33.0
# 3      1900-01-01 05:44:00       -1.0    1004.0      -18.0
# 4      1900-01-01 05:54:00       -6.0     812.0      -25.0
# ...                    ...        ...       ...        ...
# 336765 1900-01-01 22:40:00       -5.0    2334.0      -17.0
# 336766 1900-01-01 22:40:00      -10.0    2347.0      -20.0
# 336767 1900-01-01 22:41:00       -5.0    2345.0      -16.0
# 336768 1900-01-01 23:07:00       12.0    2359.0        1.0
# 336769 1900-01-01 23:49:00      -10.0     325.0      -25.0
#
# [327346 rows x 4 columns]

# %% [markdown]
# ### 7. Convert dep_time and sched_dep_time to number of minute from midnight for further calculation

# %%
df["dep_time"] = pd.to_datetime(df["dep_time"], format="%H%M", errors="coerce")
df["sched_dep_time"] = pd.to_datetime(df["sched_dep_time"], format="%H%M", errors="coerce")

df["dep_time_mins"] = df["dep_time"].dt.hour * 60 + df["dep_time"].dt.minute
df["sched_dep_time_mins"] = df["sched_dep_time"].dt.hour * 60 + df["sched_dep_time"].dt.minute
